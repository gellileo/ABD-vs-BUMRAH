# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ipl_ball_by_ball_updated.csv')

# %%
df.head(10)
# Out:
#    match_id  season  start_date                  venue  innings  ball  \
# 0    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   6.8
# 1    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   2.7
# 2    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.1
# 3    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.2
# 4    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.3
# 5    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.4
# 6    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.5
# 7    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.6
# 8    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   4.1
# 9    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   4.2
#
#                   batting_team           bowling_team     striker non_striker  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White
# 1  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 2  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 3  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 4  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
# 5  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
# 6  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 7  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 8  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
# 9  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
#
#    ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# 0  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 1  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 2  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 3  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 4  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 5  ...      1    NaN      NaN   NaN      1.0      NaN          NaN
# 6  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 7  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 8  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
# 9  ...      0    NaN      NaN   NaN      NaN      NaN          NaN
#
#    player_dismissed other_wicket_type other_player_dismissed
# 0               NaN               NaN                    NaN
# 1               NaN               NaN                    NaN
# 2               NaN               NaN                    NaN
# 3               NaN               NaN                    NaN
# 4               NaN               NaN                    NaN
# 5               NaN               NaN                    NaN
# 6               NaN               NaN                    NaN
# 7               NaN               NaN                    NaN
# 8               NaN               NaN                    NaN
# 9               NaN               NaN                    NaN
#
# [10 rows x 22 columns]

# %%
df.innings.unique()
# Out:
# array([2, 1, 4, 3, 6, 5], dtype=int64)

# %%
#3,4 represents super overs and 5,6 represents double super overs

# %%
df = df[(df.innings == 1) | (df.innings == 2)]

# %%
df.innings.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
# What are the numbers when ABD faces Bumrah?
# step 1: Filter by player names - Done
# step 2: Use these names & assign it to striker & bowler - Done
# step 3: Get the required columns - Done

# %%
df.bowling_team.unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings'],
#       dtype=object)

# %%
df[df.bowling_team == 'Mumbai Indians']['bowler'].unique()
# Out:
# array(['DS Kulkarni', 'Harbhajan Singh', 'A Nehra', 'AM Nayar',
#        'ST Jayasuriya', 'SM Pollock', 'MA Khote', 'DJ Bravo',
#        'VS Yeligati', 'SD Chitnis', 'CRD Fernando', 'DJ Thornely',
#        'RR Raje', 'DR Smith', 'A Nel', 'SL Malinga', 'Z Khan',
#        'SR Tendulkar', 'JP Duminy', 'GR Napier', 'C Nanda', 'AM Rahane',
#        'RA Shaikh', 'R McLaren', 'R Sathish', 'AG Murtaza', 'KA Pollard',
#        'AN Ahmed', 'STR Binny', 'JEC Franklin', 'MM Patel', 'RG Sharma',
#        'A Symonds', 'TL Suman', 'RW Price', 'PP Ojha', 'RP Singh',
#        'CJ McKay', 'NLTC Perera', 'RJ Peterson', 'R Shukla', 'JJ Bumrah',
#        'MG Johnson', 'JDP Oram', 'R Dhawan', 'YS Chahal', 'P Suyal',
#        'GJ Maxwell', 'NM Coulter-Nile', 'CJ Anderson', 'P Kumar',
#        'LMP Simmons', 'S Gopal', 'K Santokie', 'M de Lange',
#        'R Vinay Kumar', 'J Suchith', 'MJ McClenaghan', 'HH Pandya',
#        'TG Southee', 'KH Pandya', 'N Rana', 'KV Sharma', 'M Markande',
#        'Mustafizur Rahman', 'PJ Sangwan', 'BCJ Cutting', 'A Dananjaya',
#        'Rasikh Salam', 'RD Chahar', 'JP Behrendorff', 'AS Joseph',
#        'J Yadav', 'AS Roy', 'BB Sran', 'TA Boult', 'JL Pattinson',
#        'M Jansen', 'AF Milne', 'JDS Neesham', 'PP Chawla'], dtype=object)

# %%
# player 1: JJ Bumrah
# player 2: AB de Villiers

# %%
df[df.batting_team == 'Royal Challengers Bangalore']['striker'].unique()
# Out:
# array(['MV Boucher', 'W Jaffer', 'JH Kallis', 'CL White', 'V Kohli',
#        'R Dravid', 'P Kumar', 'Z Khan', 'SB Joshi', 'AA Noffke',
#        'B Akhil', 'LRPL Taylor', 'S Chanderpaul', 'R Vinay Kumar',
#        'B Chipli', 'DW Steyn', 'Misbah-ul-Haq', 'DT Patil', 'A Kumble',
#        'J Arunkumar', 'Abdur Razzak', 'SP Goswami', 'KP Pietersen',
#        'RV Uthappa', 'JD Ryder', 'R Bishnoi', 'KV Sharma', 'Pankaj Singh',
#        'MK Pandey', 'RE van der Merwe', 'KP Appanna', 'D du Preez',
#        'EJG Morgan', 'A Mithun', 'S Sriram', 'AUK Pathan',
#        'AB de Villiers', 'TM Dilshan', 'SS Tiwary', 'MA Agarwal',
#        'DL Vettori', 'CA Pujara', 'JJ van der Wath', 'R Ninan',
#        'S Aravind', 'CH Gayle', 'J Syed Mohammad', 'M Kaif',
#        'LA Pomersbach', 'KB Arun Karthik', 'CK Langeveldt', 'AB McDonald',
#        'HV Patel', 'RR Bhatkal', 'M Muralitharan', 'P Parameswaran',
#        'KK Nair', 'DT Christian', 'MC Henriques', 'M Kartik',
#        'JD Unadkat', 'R Rampaul', 'KL Rahul', 'A Mukund', 'Yuvraj Singh',
#        'PA Patel', 'NJ Maddinson', 'JA Morkel', 'YV Takawale', 'MA Starc',
#        'AB Dinda', 'S Rana', 'VR Aaron', 'RR Rossouw', 'YS Chahal',
#        'VH Zol', 'AN Ahmed', 'KD Karthik', 'Mandeep Singh', 'DJG Sammy',
#        'SA Abbott', 'D Wiese', 'Iqbal Abdulla', 'MS Bisla', 'SN Khan',
#        'KM Jadhav', 'SR Watson', 'TM Head', 'KW Richardson', 'STR Binny',
#        'Sachin Baby', 'Parvez Rasool', 'CJ Jordan', 'TS Mills',
#        'A Choudhary', 'P Negi', 'Vishnu Vinod', 'AF Milne', 'S Badree',
#        'CR Woakes', 'BB McCullum', 'Q de Kock', 'Washington Sundar',
#        'CJ Anderson', 'UT Yadav', 'Mohammed Siraj', 'M Vohra',
#        'C de Grandhomme', 'TG Southee', 'M Ashwin', 'MM Ali',
#        'SO Hetmyer', 'S Dube', 'NA Saini', 'P Ray Barman', 'MP Stoinis',
#        'AD Nath', 'Gurkeerat Singh', 'H Klaasen', 'D Padikkal',
#        'JR Philippe', 'AJ Finch', 'I Udana', 'CH Morris', 'Shahbaz Ahmed',
#        'GJ Maxwell', 'RM Patidar', 'KA Jamieson', 'DR Sams', 'KS Bharat',
#        'PWH de Silva', 'TH David', 'GHS Garton'], dtype=object)

# %%
   req_df = df[(df.striker == 'AB de Villiers') & (df.bowler == 'JJ Bumrah')]

# %%
req_df["striker"].unique()
# Out:
# array(['AB de Villiers'], dtype=object)

# %%
req_df["bowler"].unique()
# Out:
# array(['JJ Bumrah'], dtype=object)

# %%
# No of runs scored?
# No of balls faced?
# No of times dismissed?

# %%
# runs scored
sum(req_df.runs_off_bat)
# Out:
# 125

# %%
# balls faced
len(req_df)
# Out:
# 86

# %%
# outs
len(req_df[req_df.player_dismissed == 'AB de Villiers'])

# %%
# strike rate
100*sum(req_df.runs_off_bat)/len(req_df)
# Out:
# 145.34883720930233

# %%
# Comparision against all batsman Bumrah has bowled to

# %%
bumrah_df = df[df.bowler =='JJ Bumrah']

# %%
bumrah_df.head()
# Out:
#        match_id  season  start_date                  venue  innings  ball  \
# 76627    597999    2013  2013-04-04  M Chinnaswamy Stadium        1  12.6
# 76628    597999    2013  2013-04-04  M Chinnaswamy Stadium        1  12.5
# 76629    597999    2013  2013-04-04  M Chinnaswamy Stadium        1  12.4
# 76630    597999    2013  2013-04-04  M Chinnaswamy Stadium        1  12.3
# 76631    597999    2013  2013-04-04  M Chinnaswamy Stadium        1  12.2
#
#                       batting_team    bowling_team          striker  \
# 76627  Royal Challengers Bangalore  Mumbai Indians         CH Gayle
# 76628  Royal Challengers Bangalore  Mumbai Indians  KB Arun Karthik
# 76629  Royal Challengers Bangalore  Mumbai Indians          KK Nair
# 76630  Royal Challengers Bangalore  Mumbai Indians         CH Gayle
# 76631  Royal Challengers Bangalore  Mumbai Indians         CH Gayle
#
#            non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# 76627  KB Arun Karthik  ...      0    NaN      NaN   NaN      NaN      NaN
# 76628         CH Gayle  ...      0    NaN      NaN   NaN      NaN      NaN
# 76629         CH Gayle  ...      0    NaN      NaN   NaN      NaN      NaN
# 76630          KK Nair  ...      0    NaN      NaN   NaN      NaN      NaN
# 76631          KK Nair  ...      0    NaN      NaN   NaN      NaN      NaN
#
#        wicket_type  player_dismissed other_wicket_type other_player_dismissed
# 76627          NaN               NaN               NaN                    NaN
# 76628          NaN               NaN               NaN                    NaN
# 76629          lbw           KK Nair               NaN                    NaN
# 76630          NaN               NaN               NaN                    NaN
# 76631          NaN               NaN               NaN                    NaN
#
# [5 rows x 22 columns]

# %%
# runs scored by this batsman
bdf1 = pd.DataFrame(bumrah_df.groupby('striker')['runs_off_bat'].sum()).reset_index()

# %%
bdf2 = pd.DataFrame(bumrah_df.groupby('striker')['ball'].count()).reset_index()

# %%
bdf2.head()
# Out:
#           striker  ball
# 0        A Mishra     5
# 1  AB de Villiers    86
# 2         AD Nath     4
# 3      AD Russell    41
# 4        AJ Finch    29

# %%
bdf3 = bdf1.merge(bdf2, on = 'striker', how = 'left')

# %%
bdf3.head(10)
# Out:
#           striker  runs_off_bat  ball
# 0        A Mishra             1     5
# 1  AB de Villiers           125    86
# 2         AD Nath             4     4
# 3      AD Russell            51    41
# 4        AJ Finch            24    29
# 5       AJ Turner             0     1
# 6          AJ Tye            11     7
# 7      AK Markram             2     2
# 8       AM Rahane            43    35
# 9        AR Patel            21    32

# %%
bdf3['strike_rate'] = 100*bdf3['runs_off_bat']/bdf3['ball']

# %%
bdf3.head(10)
# Out:
#           striker  runs_off_bat  ball  strike_rate
# 0        A Mishra             1     5    20.000000
# 1  AB de Villiers           125    86   145.348837
# 2         AD Nath             4     4   100.000000
# 3      AD Russell            51    41   124.390244
# 4        AJ Finch            24    29    82.758621
# 5       AJ Turner             0     1     0.000000
# 6          AJ Tye            11     7   157.142857
# 7      AK Markram             2     2   100.000000
# 8       AM Rahane            43    35   122.857143
# 9        AR Patel            21    32    65.625000

# %%
# min criteria: 30 balls

# %%
bdf3 = bdf3[bdf3.ball >= 30]

# %%
bdf3.head()
# Out:
#            striker  runs_off_bat  ball  strike_rate
# 1   AB de Villiers           125    86   145.348837
# 3       AD Russell            51    41   124.390244
# 8        AM Rahane            43    35   122.857143
# 9         AR Patel            21    32    65.625000
# 12       AT Rayudu            48    34   141.176471

# %%
abd_df = df[df.striker =='AB de Villiers']

# %%
# runs scored by this batsman
adf1 = pd.DataFrame(abd_df.groupby('bowler')['runs_off_bat'].sum()).reset_index()

# %%
adf1.head()
# Out:
#            bowler  runs_off_bat
# 0  A Ashish Reddy            46
# 1      A Chandila            26
# 2      A Flintoff            34
# 3        A Kumble            39
# 4        A Mishra            40

# %%
# balls faced
adf2 = pd.DataFrame(abd_df.groupby('bowler')['ball'].count()).reset_index()

# %%
adf2.head()
# Out:
#            bowler  ball
# 0  A Ashish Reddy    18
# 1      A Chandila    11
# 2      A Flintoff    12
# 3        A Kumble    41
# 4        A Mishra    37

# %%
adf3 = adf1.merge(adf2, on = 'bowler', how = 'left')

# %%
adf3.head(10)
# Out:
#            bowler  runs_off_bat  ball
# 0  A Ashish Reddy            46    18
# 1      A Chandila            26    11
# 2      A Flintoff            34    12
# 3        A Kumble            39    41
# 4        A Mishra            40    37
# 5         A Nehra            61    29
# 6        A Nortje            16    11
# 7         A Singh            11     7
# 8       A Symonds            15    12
# 9        A Uniyal             1     1

# %%
adf3['strike_rate'] = 100*adf3['runs_off_bat']/adf3['ball']

# %%
adf3.head(10)
# Out:
#             bowler  runs_off_bat  ball  strike_rate
# 0         A Kumble            39    41    95.121951
# 1         A Mishra            40    37   108.108108
# 2       AD Russell            87    39   223.076923
# 3         AR Patel            71    70   101.428571
# 4          B Kumar            68    43   158.139535
# 5        CH Morris            71    35   202.857143
# 6         DJ Bravo            72    47   153.191489
# 7      DS Kulkarni            50    38   131.578947
# 8        HH Pandya            88    39   225.641026
# 9  Harbhajan Singh           110    81   135.802469

# %%
# min criteria : 30 balls

# %%
adf3 = adf3[adf3.ball >= 30]

# %%
# bdf3, adf3

# %%
bdf3.reset_index(inplace = True, drop = True)
adf3.reset_index(inplace = True, drop = True)

# %%
plt.figure(figsize=(16,8))
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)
for i in range(len(bdf3)):
    if bdf3["striker"][i]=="V Kohli":
        plt.text(bdf3['strike_rate'][i]+1 , bdf3['runs_off_bat'][i]+1 , bdf3['striker'][i] )
    elif bdf3["striker"][i]=="AB de Villiers":
        plt.text(bdf3['strike_rate'][i]-10 , bdf3['runs_off_bat'][i]+1 , bdf3['striker'][i],color= 'maroon')
    else:
        plt.text(bdf3['strike_rate'][i]-10 , bdf3['runs_off_bat'][i]+1 , bdf3['striker'][i] )
        
    
plt.axvline(120, ls = '--', color = 'grey')
plt.axhline(60, ls = '--', color = 'grey')
plt.title('Batsman against Bumrah in IPL (min 30 balls faced)', fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Best Batsman against Bumrah in IPL.jpg')
plt.show()

# %%
plt.figure(figsize = (16,8))

plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)

for i in range(len(bdf3)):
    if bdf3.striker[i] == 'V Kohli':
        plt.text(bdf3.strike_rate[i] +1, bdf3.runs_off_bat[i]+1 , bdf3.striker[i])
    elif bdf3.striker[i] == 'AB de Villiers':
        plt.text(bdf3.strike_rate[i] -10, bdf3.runs_off_bat[i] +1, bdf3.striker[i], color = 'maroon')
    elif (bdf3.striker[i] == 'S Dhawan') | (bdf3.striker[i] == 'KL Rahul') | (bdf3.striker[i] == 'JP Duminy'):
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])

plt.axvline(120, ls = '--', color = 'grey')
plt.axhline(60, ls = '--', color = 'grey')
plt.title("Best Batman against Bumrah", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Best Batsman against Bumrah.jpg')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.scatter(adf3.strike_rate, adf3.runs_off_bat)

for i in range(len(adf3)):
    if adf3.bowler[i] == 'JJ Bumrah':
        plt.text(adf3.strike_rate[i] + 2, adf3.runs_off_bat[i] - 1, adf3.bowler[i], color = 'maroon')
    elif (adf3.bowler[i] == 'RA Jadeja') | (adf3.bowler[i] == 'SL Malinga') | (adf3.bowler[i] == 'Sandeep Sharma') | (adf3.bowler[i] == 'Harbhajan Singh'):
        plt.text(adf3.strike_rate[i] + 2, adf3.runs_off_bat[i] - 1, adf3.bowler[i])
    elif (adf3.bowler[i] == 'HH Pandya'):
        plt.text(adf3.strike_rate[i], adf3.runs_off_bat[i] + 2, adf3.bowler[i])
    else:
        plt.text(adf3.strike_rate[i] - 3, adf3.runs_off_bat[i] - 3, adf3.bowler[i])

plt.axvline(110, ls = '--', color = 'grey')
plt.axhline(80, ls = '--', color = 'grey')
plt.title("ABD's Favorite Bowlers", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Chart_ABD_vs_Bumrah_part2.jpg')
plt.show()
